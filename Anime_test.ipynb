# %%
from fastai.collab import *
from fastai.tabular import *

import pandas as pd

# %%
path = Path("/home/sloth/datasets/anime/anime-recommendations-database")

# %%
path
# Out:
# PosixPath('/home/sloth/datasets/anime/anime-recommendations-database')

# %%
anime = pd.read_csv(path/"anime_type_genre.csv")

# %%
anime.head()
# Out:
#    Unnamed: 0  anime_id                              name  \
# 0           0     32281                    Kimi no Na wa.
# 1           1      5114  Fullmetal Alchemist: Brotherhood
# 2           2     28977                          Gintama°
# 3           3      9253                       Steins;Gate
# 4           4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members  g0  g1  ...  g40  g41  g42  Movie  TV  OVA  Special  Music  ONA  \
# ...

# %%
anime_rating = anime_name.merge(rating, on="anime_id")
anime_rating.head()
# Out:
#    anime_id            name episodes  rating_x  members  g0  g1  g2  g3  g4  \
# 0     32281  Kimi no Na wa.        1      9.37   200630   1   1   1   1   0
# 1     32281  Kimi no Na wa.        1      9.37   200630   1   1   1   1   0
# 2     32281  Kimi no Na wa.        1      9.37   200630   1   1   1   1   0
# 3     32281  Kimi no Na wa.        1      9.37   200630   1   1   1   1   0
# 4     32281  Kimi no Na wa.        1      9.37   200630   1   1   1   1   0
#
#    ...  g42  Movie  TV  OVA  Special  Music  ONA  Other  user_id  rating_y
# 0  ...    0      1   0    0        0      0    0      0       99         5
# 1  ...    0      1   0    0        0      0    0      0      152        10
# 2  ...    0      1   0    0        0      0    0      0      244        10
# 3  ...    0      1   0    0        0      0    0      0      271        10
# 4  ...    0      1   0    0        0      0    0      0      322        10
#
# [5 rows x 57 columns]

# %%
anime_rating = anime_rating.rename(columns={"rating_x" : "avg_rating", "rating_y": "user_rating"})
anime_rating.head()
# Out:
#    anime_id            name episodes  avg_rating  members  g0  g1  g2  g3  g4  \
# 0     32281  Kimi no Na wa.        1        9.37   200630   1   1   1   1   0
# 1     32281  Kimi no Na wa.        1        9.37   200630   1   1   1   1   0
# 2     32281  Kimi no Na wa.        1        9.37   200630   1   1   1   1   0
# 3     32281  Kimi no Na wa.        1        9.37   200630   1   1   1   1   0
# 4     32281  Kimi no Na wa.        1        9.37   200630   1   1   1   1   0
#
#    ...  g42  Movie  TV  OVA  Special  Music  ONA  Other  user_id  user_rating
# 0  ...    0      1   0    0        0      0    0      0       99            5
# 1  ...    0      1   0    0        0      0    0      0      152           10
# 2  ...    0      1   0    0        0      0    0      0      244           10
# 3  ...    0      1   0    0        0      0    0      0      271           10
# 4  ...    0      1   0    0        0      0    0      0      322           10
#
# [5 rows x 57 columns]

# %%
anime_rating.to_csv(path/"anime_rating.csv")

# %%
anime_name = anime.drop(["Unnamed: 0", "genre", "type"], axis = 1)

# %%
anime = anime_name.rename(columns={"rating": "avg_rating"})

# %%
anime = anime.dropna()

# %%
anime.to_csv(path/"anime_clean.csv",index=False)

# %%
rating = pd.read_csv(path/"rating_clean.csv")

# %%
rating = rating.rename(columns={"rating": "user_rating"})

# %%
rating = rating.drop(ratings[ratings.rating == -1].index)

# %%
rating.head()
# Out:
#    user_id  anime_id  user_rating
# 0        1      8074           10
# 1        1     11617           10
# 2        1     11757           10
# 3        1     15451           10
# 4        2     11771           10

# %%
rating.to_csv(path/"rating_clean.csv", index=False)

# %%
rating = rating.reset_index(drop=True)

# %%
rating.head()
# Out:
#    user_id  anime_id  rating
# 0        1      8074      10
# 1        1     11617      10
# 2        1     11757      10
# 3        1     15451      10
# 4        2     11771      10

# %% [raw]
# rating_dropped.head()

# %%
#creating a dictonary with keys being genres and values being 0
it = ratings.itertuples()
thing = {}
for item in it:
    thing.update({item[4]: 1})

# %%
it = ratings.itertuples()
new = {}
count = 0;
for item in it:
    if item[4] == "Movie":
        array = [item[1], 1, 0, 0, 0 ,0 ,0 , 0]
    elif item[4] == "TV":
        array = [item[1], 0, 1, 0, 0 ,0 ,0 , 0]
    elif item[4] == "OVA":
        array = [item[1], 0, 0, 1, 0 ,0 ,0 , 0]
    elif item[4] == "Special":
        array = [item[1], 0, 0, 0, 1 ,0 ,0 , 0]
    elif item[4] == "Music":
        array = [item[1], 0, 0, 0, 0 ,1 ,0 , 0]
    elif item[4] == "ONA":
        array = [item[1], 0, 0, 0, 0 ,0 ,1 , 0]
    elif item[4] == "nan":
        array = [item[1], 0, 0, 0, 0 ,0 ,0 , 1]
    new.update({count:array})
    count += 1

# %%
type_df = pd.DataFrame.from_dict(new, orient="index", columns = ["anime_id",'Movie', 'TV', 'OVA', 'Special', 'Music', 'ONA', "Other"])

# %%
type_df.head()
# Out:
#    anime_id  Movie  TV  OVA  Special  Music  ONA  Other
# 0     32281      1   0    0        0      0    0      0
# 1      5114      0   1    0        0      0    0      0
# 2     28977      0   1    0        0      0    0      0
# 3      9253      0   1    0        0      0    0      0
# 4      9969      0   1    0        0      0    0      0

# %%
{'Movie': 1, 'TV': 1, 'OVA': 1, 'Special': 1, 'Music': 1, 'ONA': 1, nan: 1}

# %%
# Out:
# 1
