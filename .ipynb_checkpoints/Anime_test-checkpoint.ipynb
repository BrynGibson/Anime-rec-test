# %%
from fastai.collab import *
from fastai.tabular import *

import pandas as pd

# %%
path = Path("/home/sloth/datasets/anime/anime-recommendations-database")

# %%
path
# Out:
# PosixPath('/home/sloth/datasets/anime/anime-recommendations-database')

# %%
ratings = pd.read_csv(path/"anime.csv")

# %%
ratings.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
#creating new dataframe without animes with no genres
ratings_new = ratings[ratings['genre'].notnull()]

# %%
ratings_new.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
#creating a dictonary with keys being genres and values being 0
it = ratings_new.itertuples()
d = {}
for i in it:
    for item in i[3].split(","):
        d.update({item.strip():0})

# %%
d
# Out:
# {'Drama': 0,
#  'Romance': 0,
#  'School': 0,
#  'Supernatural': 0,
#  'Action': 0,
#  'Adventure': 0,
#  'Fantasy': 0,
#  'Magic': 0,
#  'Military': 0,
#  'Shounen': 0,
#  'Comedy': 0,
#  'Historical': 0,
#  'Parody': 0,
#  'Samurai': 0,
#  'Sci-Fi': 0,
#  'Thriller': 0,
#  'Sports': 0,
#  'Super Power': 0,
#  'Space': 0,
#  'Slice of Life': 0,
#  'Mecha': 0,
#  'Music': 0,
#  'Mystery': 0,
#  'Seinen': 0,
#  'Martial Arts': 0,
#  'Vampire': 0,
#  'Shoujo': 0,
#  'Horror': 0,
#  'Police': 0,
#  'Psychological': 0,
#  'Demons': 0,
#  'Ecchi': 0,
#  'Josei': 0,
#  'Shounen Ai': 0,
#  'Game': 0,
#  'Dementia': 0,
#  'Harem': 0,
#  'Cars': 0,
#  'Kids': 0,
#  'Shoujo Ai': 0,
#  'Hentai': 0,
#  'Yaoi': 0,
#  'Yuri': 0}

# %%
#creating list of keys
gns = list(d.keys())

# %%
#creating list of id anime ids
it = ratings_new.itertuples()
ids = []
for i in it:
    ids.append(i[1])

# %%
#creating dictonary with animeids as keys and dictonary of genres as the values.
ids_dict = {}
for i in ids:
    ids_dict.update({i:d})

# %%
ids_dict
# Out:
# {32281: {'Drama': 0,
#   'Romance': 0,
#   'School': 0,
#   'Supernatural': 0,
#   'Action': 0,
#   'Adventure': 0,
#   'Fantasy': 0,
#   'Magic': 0,
#   'Military': 0,
#   'Shounen': 0,
#   'Comedy': 0,
#   'Historical': 0,
#   'Parody': 0,
#   'Samurai': 0,
#   'Sci-Fi': 0,
#   'Thriller': 0,
#   'Sports': 0,
#   'Super Power': 0,
#   'Space': 0,
#   'Slice of Life': 0,
#   'Mecha': 0,
#   'Music': 0,
#   'Mystery': 0,
#   'Seinen': 0,
#   'Martial Arts': 0,
#   'Vampire': 0,
#   'Shoujo': 0,
#   'Horror': 0,
#   'Police': 0,
#   'Psychological': 0,
#   'Demons': 0,
#   'Ecchi': 0,
#   'Josei': 0,
#   'Shounen Ai': 0,
#   'Game': 0,
#   'Dementia': 0,
#   'Harem': 0,
#   'Cars': 0,
#   'Kids': 0,
#   'Shoujo Ai': 0,
#   'Hentai': 0,
#   'Yaoi': 0,
#   'Yuri': 0},
#  5114: {'Drama': 0,
#   'Romance': 0,
#   'School': 0,
#   'Supernatural': 0,
#   'Action': 0,
#   'Adventure': 0,
#   'Fantasy': 0,
#   'Magic': 0,
#   'Military': 0,
#   'Shounen': 0,
#   'Comedy': 0,
# ...

# %%
#this cell is to iterate through the dataframe and update the value for each anime genre to 1 if it has been tagged with that genre
it = ratings_new.itertuples()
#iterating through df 
for i in it:
    #splitting string into genre strings and iterating through
    for item in i[3].split(","):
        # g is genre string parsed from list of genres
        g = item.strip()
        # i[1] should give the animeid to use a key for updating the ids_dict
        # i[1][g] = 1 should update the value to 1 on each genre that each anime is tagged for
        # it instead updates all to one and i cant figure out why
        ids_dict[i[1]][g] += 1

# %%
ids_dict
# Out:
# {32281: {'Drama': 2017,
#   'Romance': 1465,
#   'School': 1221,
#   'Supernatural': 1038,
#   'Action': 2846,
#   'Adventure': 2349,
#   'Fantasy': 2310,
#   'Magic': 779,
#   'Military': 427,
#   'Shounen': 1713,
#   'Comedy': 4646,
#   'Historical': 807,
#   'Parody': 409,
#   'Samurai': 149,
#   'Sci-Fi': 2071,
#   'Thriller': 88,
#   'Sports': 544,
#   'Super Power': 466,
#   'Space': 382,
#   'Slice of Life': 1221,
#   'Mecha': 945,
#   'Music': 861,
#   'Mystery': 496,
#   'Seinen': 548,
#   'Martial Arts': 266,
#   'Vampire': 103,
#   'Shoujo': 604,
#   'Horror': 370,
#   'Police': 198,
#   'Psychological': 230,
#   'Demons': 295,
#   'Ecchi': 638,
#   'Josei': 55,
#   'Shounen Ai': 66,
#   'Game': 182,
#   'Dementia': 241,
#   'Harem': 318,
#   'Cars': 73,
#   'Kids': 1610,
#   'Shoujo Ai': 56,
#   'Hentai': 1142,
#   'Yaoi': 40,
#   'Yuri': 43},
#  5114: {'Drama': 2017,
#   'Romance': 1465,
#   'School': 1221,
#   'Supernatural': 1038,
#   'Action': 2846,
# ...
